# %% [markdown]
# ## B.1 Simple Data Types

# %% [markdown]
# ### B.1.1 Numbers

# %%
20
# Out:
# 20

# %%
-13
# Out:
# -13

# %%
7.349
# Out:
# 7.349

# %% [markdown]
# ### B.1.2 Strings

# %%
'Good morning'
# Out:
# 'Good morning'

# %%
"Good afternoon"
# Out:
# 'Good afternoon'

# %%
"""Good night"""
# Out:
# 'Good night'

# %%
"$15 dollars!"
# Out:
# '$15 dollars!'

# %%
""
# Out:
# ''

# %%
"Python"[3]
# Out:
# 'h'

# %%
"Python"[-4]
# Out:
# 't'

# %%
"Python"[2:5]
# Out:
# 'tho'

# %%
# The two lines below are equivalent
"Python"[0:4]
"Python"[:4]
# Out:
# 'Pyth'

# %%
# The two lines below are equivalent
"Python"[3:6]
"Python"[3:]
# Out:
# 'hon'

# %%
"Python"[1:-1]
# Out:
# 'ytho'

# %%
"Python"[0:6:2]
# Out:
# 'Pto'

# %% [markdown]
# ### B.1.3  Booleans

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %% [markdown]
# ### B.1.4 The None Object

# %%
None

# %% [markdown]
# ## B.2 Operators

# %% [markdown]
# ### B.2.1 Mathematical Operators

# %%
3 + 5
# Out:
# 8

# %%
3 - 5
# Out:
# -2

# %%
3 * 5
# Out:
# 15

# %%
# 3 to the power of 5
3 ** 5
# Out:
# 243

# %%
# 3 divided by 5
3 / 5
# Out:
# 0.6

# %%
18 / 6
# Out:
# 3.0

# %%
5 % 3
# Out:
# 2

# %%
8 / 3
# Out:
# 2.6666666666666665

# %%
8 // 3
# Out:
# 2

# %%
"race" + "car"
# Out:
# 'racecar'

# %%
"Mahi" * 2
# Out:
# 'MahiMahi'

# %%
# 3 + "5"

# %% [markdown]
# ### B.2.2 Equality and Inequality Operators

# %%
10 == 10
# Out:
# True

# %%
10 == 20
# Out:
# False

# %%
"Hello" == "Hello"
# Out:
# True

# %%
"Hello" == "Goodbye"
# Out:
# False

# %%
"Hello" == "hello"
# Out:
# False

# %%
10 != 20
# Out:
# True

# %%
"Hello" != "Goodbye"
# Out:
# True

# %%
10 != 10
# Out:
# False

# %%
"Hello" != "Hello"
# Out:
# False

# %%
# Checks if 5 is less than 3
-5 < 3
# Out:
# True

# %%
# Checks if 5 is greater than 7
5 > 7
# Out:
# False

# %%
# Checks if 11 is less than or equal to 11
11 <= 11
# Out:
# True

# %%
# Checks if 4 is greater than or equal to 5
4 >= 5
# Out:
# False

# %% [markdown]
# ## B.3 Variables

# %%
name = "Boris"
age = 28
high_school_gpa = 3.7
is_handsome = True

# %%
name
# Out:
# 'Boris'

# %%
age = 35
age
# Out:
# 35

# %%
age = age + 10
age
# Out:
# 45

# %%
high_school_gpa = "A+"

# %%
# last_name

# %% [markdown]
# ## B.4 Functions

# %% [markdown]
# ### B.4.1 Arguments and Return Values

# %%
len("Python is fun")
# Out:
# 13

# %%
int("20")
# Out:
# 20

# %%
float("14.3")
# Out:
# 14.3

# %%
str(5)
# Out:
# '5'

# %%
# int("xyz")

# %%
value = 10
print(value)

value = value - 3
print(value)

value = value * 4
print(value)

value = value / 2
print(value)
# Out:
# 10
# 7
# 28
# 14.0

# %%
print("Cherry", "Strawberry", "Key Lime")
# Out:
# Cherry Strawberry Key Lime

# %%
print("Cherry", "Strawberry", "Key Lime", sep = "!")
# Out:
# Cherry!Strawberry!Key Lime

# %%
print("Cherry", "Strawberry", "Key Lime")
print("Cherry", "Strawberry", "Key Lime", sep=" ")
# Out:
# Cherry Strawberry Key Lime
# Cherry Strawberry Key Lime

# %%
print("Cherry", "Strawberry", "Key Lime", sep="*!*")
# Out:
# Cherry*!*Strawberry*!*Key Lime

# %%
print("Cherry", "Strawberry", "Key Lime", sep="!", end="\n")
print("Peach Cobbler")
# Out:
# Cherry!Strawberry!Key Lime
# Peach Cobbler

# %%
print("Cherry", "Strawberry", "Key Lime", sep="!", end="***")
print("Peach Cobbler")
# Out:
# Cherry!Strawberry!Key Lime***Peach Cobbler

# %%
print(
    "Cherry", "Strawberry", "Key Lime", sep="!", end="***"
)
# Out:
# Cherry!Strawberry!Key Lime***

# %%
print(
    "Cherry",
    "Strawberry",
    "Key Lime",
    sep="!",
    end="***",
)
# Out:
# Cherry!Strawberry!Key Lime***

# %% [markdown]
# ### B.4.2 Custom Functions

# %%
def convert_to_fahrenheit(celsius_temp):
    first_step = celsius_temp * (9 / 5)
    fahrenheit_temperature = first_step + 32
    return fahrenheit_temperature

# %%
convert_to_fahrenheit(10)
# Out:
# 50.0

# %%
convert_to_fahrenheit(celsius_temp = 10)
# Out:
# 50.0

# %% [markdown]
# ## B.5 Modules

# %%
import datetime

# %%
import datetime as dt

# %% [markdown]
# ## B.6 Classes and Objects

# %%
type("peanut butter")
# Out:
# str

# %%
type("jelly")
# Out:
# str

# %%
da_vinci_birthday = dt.date(1452, 4, 15)
da_vinci_birthday
# Out:
# datetime.date(1452, 4, 15)

# %% [markdown]
# ### B.6.1 Attributes and Methods

# %%
da_vinci_birthday.day
# Out:
# 15

# %%
da_vinci_birthday.month
# Out:
# 4

# %%
da_vinci_birthday.year
# Out:
# 1452

# %%
da_vinci_birthday.weekday()
# Out:
# 3

# %% [markdown]
# ## B.7 String Methods

# %%
"Hello".upper()
# Out:
# 'HELLO'

# %%
greeting = "Hello"
greeting.upper()
# Out:
# 'HELLO'

# %%
greeting
# Out:
# 'Hello'

# %%
"1611 BROADWAY".lower()
# Out:
# '1611 broadway'

# %%
"uPsIdE dOwN".swapcase()
# Out:
# 'UpSiDe DoWn'

# %%
"Sally Sells Seashells by the Seashore".replace("S", "$")
# Out:
# '$ally $ells $eashells by the $eashore'

# %%
"  ".isspace()
# Out:
# True

# %%
"3 Amigos".isspace()
# Out:
# False

# %%
data = "    10/31/2019  "
data.rstrip()
# Out:
# '    10/31/2019'

# %%
data.lstrip()
# Out:
# '10/31/2019  '

# %%
data.strip()
# Out:
# '10/31/2019'

# %%
"robert".capitalize()
# Out:
# 'Robert'

# %%
"once upon a time".title()
# Out:
# 'Once Upon A Time'

# %%
"BENJAMIN FRANKLIN".lower().title()
# Out:
# 'Benjamin Franklin'

# %%
"tuna" in "fortunate"
# Out:
# True

# %%
"salmon" in "fortunate"
# Out:
# False

# %%
"factory".startswith("fact")
# Out:
# True

# %%
"garage".endswith("rage")
# Out:
# True

# %%
"celebrate".count("e")
# Out:
# 3

# %%
"celebrate".find("e")
# Out:
# 1

# %%
"celebrate".index("e")
# Out:
# 1

# %%
"celebrate".find("z")
# Out:
# -1

# %%
# "celebrate".index("z")

# %% [markdown]
# ## B.8 Lists

# %%
backstreet_boys = ["Nick", "AJ", "Brian", "Howie", "Kevin"]

# %%
len(backstreet_boys)
# Out:
# 5

# %%
[]
# Out:
# []

# %%
prime_numbers = [2, 3, 5, 7, 11]

# %%
stock_prices_for_last_four_days = [99.93, 105.23, 102.18, 94.45]

# %%
settings = [True, False, False, True, True, False]

# %%
motley_crew = ["rhinoceros", 42, False, 100.05]

# %%
favorite_foods = ["Sushi", "Steak", "Barbeque"]

# %%
favorite_foods = ["Sushi", "Steak", "Barbeque",]

# %%
favorite_foods = [
    "Sushi",
    "Steak",
    "Barbeque",
]

# %%
favorite_foods[1]
# Out:
# 'Steak'

# %%
# Extract elements from index positions 1 to 3 (exclusive)
favorite_foods[1:3]
# Out:
# ['Steak', 'Barbeque']

# %%
# Extract elements from start of the list to index 2 (exclusive)
favorite_foods[:2]
# Out:
# ['Sushi', 'Steak']

# %%
# Extract elements from index 2 to the end of the list
favorite_foods[2:]
# Out:
# ['Barbeque']

# %%
# Extract elements from index positions 0 (inclusive)
# to 3 (exclusive) in increments of 2
favorite_foods[0:3:2]
# Out:
# ['Sushi', 'Barbeque']

# %%
favorite_foods.append("Burrito")
favorite_foods
# Out:
# ['Sushi', 'Steak', 'Barbeque', 'Burrito']

# %%
favorite_foods.extend(["Tacos", "Pizza", "Cheeseburger"])
favorite_foods
# Out:
# ['Sushi', 'Steak', 'Barbeque', 'Burrito', 'Tacos', 'Pizza', 'Cheeseburger']

# %%
favorite_foods.insert(2, "Pasta")
favorite_foods
# Out:
# ['Sushi',
#  'Steak',
#  'Pasta',
#  'Barbeque',
#  'Burrito',
#  'Tacos',
#  'Pizza',
#  'Cheeseburger']

# %%
"Pizza" in favorite_foods
# Out:
# True

# %%
"Caviar" in favorite_foods
# Out:
# False

# %%
"Pizza" not in favorite_foods
# Out:
# False

# %%
"Caviar" not in favorite_foods
# Out:
# True

# %%
favorite_foods.append("Pasta")
favorite_foods
# Out:
# ['Sushi',
#  'Steak',
#  'Pasta',
#  'Barbeque',
#  'Burrito',
#  'Tacos',
#  'Pizza',
#  'Cheeseburger',
#  'Pasta']

# %%
favorite_foods.count("Pasta")
# Out:
# 2

# %%
favorite_foods.remove("Pasta")
favorite_foods
# Out:
# ['Sushi',
#  'Steak',
#  'Barbeque',
#  'Burrito',
#  'Tacos',
#  'Pizza',
#  'Cheeseburger',
#  'Pasta']

# %%
favorite_foods.pop()
# Out:
# 'Pasta'

# %%
favorite_foods
# Out:
# ['Sushi', 'Steak', 'Barbeque', 'Burrito', 'Tacos', 'Pizza', 'Cheeseburger']

# %%
favorite_foods.pop(2)
# Out:
# 'Barbeque'

# %%
favorite_foods
# Out:
# ['Sushi', 'Steak', 'Burrito', 'Tacos', 'Pizza', 'Cheeseburger']

# %%
spreadsheet = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# %% [markdown]
# ### B.8.1 List Iteration

# %%
for season in ["Winter", "Spring", "Summer", "Fall"]:
    print(season)
# Out:
# Winter
# Spring
# Summer
# Fall

# %%
letter_count = 0

for season in ["Winter", "Spring", "Summer", "Fall"]:
    letter_count = letter_count + len(season)

letter_count
# Out:
# 22

# %% [markdown]
# ### B.8.2 List Comprehension

# %%
numbers = [4, 8, 15, 16, 23, 42]

# %%
squares = []

for number in numbers:
    squares.append(number ** 2)

squares
# Out:
# [16, 64, 225, 256, 529, 1764]

# %%
squares = [number ** 2 for number in numbers]
squares
# Out:
# [16, 64, 225, 256, 529, 1764]

# %% [markdown]
# ### B.8.3. Converting a String to a List and Vice Versa

# %%
empire_state_bldg = "20 West 34th Street, New York, NY, 10001"

# %%
empire_state_bldg.split(",")
# Out:
# ['20 West 34th Street', ' New York', ' NY', ' 10001']

# %%
empire_state_bldg.split(", ")
# Out:
# ['20 West 34th Street', 'New York', 'NY', '10001']

# %%
chrysler_bldg = ["405 Lexington Ave", "New York", "NY", "10174"]

# %%
", ".join(chrysler_bldg)
# Out:
# '405 Lexington Ave, New York, NY, 10174'

# %% [markdown]
# ## B.9 Tuples

# %%
"Rock", "Pop", "Country"
# Out:
# ('Rock', 'Pop', 'Country')

# %%
music_genres = ("Rock", "Pop", "Country")
music_genres
# Out:
# ('Rock', 'Pop', 'Country')

# %%
len(music_genres)
# Out:
# 3

# %%
one_hit_wonders = ("Never Gonna Give You Up")
one_hit_wonders
# Out:
# 'Never Gonna Give You Up'

# %%
one_hit_wonders = ("Never Gonna Give You Up", )
one_hit_wonders
# Out:
# ('Never Gonna Give You Up',)

# %%
empty_tuple = tuple()
empty_tuple
# Out:
# ()

# %%
len(empty_tuple)
# Out:
# 0

# %% [markdown]
# ## B.10 Dictionaries

# %%
{}
# Out:
# {}

# %%
{ "Cheeseburger": 7.99 }
# Out:
# {'Cheeseburger': 7.99}

# %%
menu = {"Cheeseburger": 7.99, "French Fries": 2.99, "Soda": 2.99}
menu
# Out:
# {'Cheeseburger': 7.99, 'French Fries': 2.99, 'Soda': 2.99}

# %%
len(menu)
# Out:
# 3

# %%
menu["French Fries"]
# Out:
# 2.99

# %%
# menu["Steak"]

# %%
# menu["soda"]

# %%
menu["Taco"] = 0.99
menu
# Out:
# {'Cheeseburger': 7.99, 'French Fries': 2.99, 'Soda': 2.99, 'Taco': 0.99}

# %%
print(menu["Cheeseburger"])
menu["Cheeseburger"] = 9.99
print(menu["Cheeseburger"])
# Out:
# 7.99
# 9.99

# %%
menu.pop("French Fries")
# Out:
# 2.99

# %%
menu
# Out:
# {'Cheeseburger': 9.99, 'Soda': 2.99, 'Taco': 0.99}

# %%
"Soda" in menu
# Out:
# True

# %%
"Spaghetti" in menu
# Out:
# False

# %%
1.99 in menu.values()
# Out:
# False

# %%
499.99 in menu.values()
# Out:
# False

# %% [markdown]
# ### B.10.1 Dictionary Iteration

# %%
capitals = {
    "New York": "Albany",
    "Florida": "Tallahassee",
    "California": "Sacramento"
}

for state, capital in capitals.items():
    print("The capital of " + state + " is " + capital + ".")
# Out:
# The capital of New York is Albany.
# The capital of Florida is Tallahassee.
# The capital of California is Sacramento.

# %% [markdown]
# ## B.11 Sets

# %%
favorite_numbers = { 4, 8, 15, 16, 23, 42 }

# %%
set()
# Out:
# set()

# %%
favorite_numbers.add(100)
favorite_numbers
# Out:
# {4, 8, 15, 16, 23, 42, 100}

# %%
favorite_numbers.add(15)
favorite_numbers
# Out:
# {4, 8, 15, 16, 23, 42, 100}

# %%
# favorite_numbers[2]

# %% [markdown]
# ### B.11.1 Set Operations

# %%
candy_bars = { "Milky Way", "Snickers", "100 Grand" }
sweet_things = { "Sour Patch Kids", "Reeses Pieces", "Snickers" }

# %%
candy_bars.intersection(sweet_things)
# Out:
# {'Snickers'}

# %%
candy_bars & sweet_things
# Out:
# {'Snickers'}

# %%
candy_bars.union(sweet_things)
# Out:
# {'100 Grand', 'Milky Way', 'Reeses Pieces', 'Snickers', 'Sour Patch Kids'}

# %%
candy_bars | sweet_things
# Out:
# {'100 Grand', 'Milky Way', 'Reeses Pieces', 'Snickers', 'Sour Patch Kids'}

# %%
candy_bars.difference(sweet_things)
# Out:
# {'100 Grand', 'Milky Way'}

# %%
candy_bars - sweet_things
# Out:
# {'100 Grand', 'Milky Way'}

# %%
candy_bars.symmetric_difference(sweet_things)
# Out:
# {'100 Grand', 'Milky Way', 'Reeses Pieces', 'Sour Patch Kids'}

# %%
candy_bars ^ sweet_things
# Out:
# {'100 Grand', 'Milky Way', 'Reeses Pieces', 'Sour Patch Kids'}

# %% [markdown]
# ## B.12 Summary
